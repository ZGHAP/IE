# %%
#select * from AINDEXMEMBERS
#where S_INFO_WINDCODE = '000300.SH' and YEAR(OPDATE)='2016' and MONTH(OPDATE)='12' and DAY(OPDATE)='09'

#注意FIND_IN_SET中的字符串中，代码间不能有空格，否则只有第一个代码有效
#另外尽量不要用OPDATE作为时间控制字段
#select * from ASHAREINTENSITYTREND
#where YEAR(OPDATE)='2016' and MONTH(OPDATE)='12' and DAY(OPDATE)='09'
#and FIND_IN_SET(S_INFO_WINDCODE,'603099.SH,002302.SZ')

#select * from ASHARECALENDAR where FIND_IN_SET(S_INFO_EXCHMARKET,'SZSE,SSE') and TRADE_DAYS BETWEEN 20110407 
#and 20110430 ORDER BY TRADE_DAYS desc limit 2
#select * from ASHARECALENDAR where FIND_IN_SET(S_INFO_EXCHMARKET,'SZSE,SSE') and TRADE_DAYS LIKE '202005%' ORDER BY TRADE_DAYS desc limit 2
#select TRADE_DAYS from ASHARECALENDAR where FIND_IN_SET(S_INFO_EXCHMARKET,'SSE') and TRADE_DAYS LIKE '202005%' ORDER BY TRADE_DAYS desc limit 1

# %%
import numpy as np
import pandas as pd
import rqdatac as rq
import calendar
import pymysql
import os
import re
import sqlalchemy
from sqlalchemy import create_engine

from rqdatac import *
from datetime import datetime, timedelta, date
from collections import OrderedDict
from dateutil.parser import parse
from dateutil.relativedelta import relativedelta
from Core.params import connect_info

work_dir = os.path.dirname(os.path.abspath('__file__'))
file_path = os.path.join(work_dir, 'factor_preprocess', 'factors_rq')
save_path = os.path.join(work_dir, 'factor_preprocess', 'factors')
print(file_path)

engine = create_engine(connect_info)

global file_path, save_path, industry_benchmark
# Out:
# /AI2/IE/factor_preprocess/factors_rq

# %%
dates = ["2019-1-1", date.today().strftime('%Y-%m-%d')]
start, end = [datetime.strptime(_, "%Y-%m-%d") for _ in dates]
dates_dict = OrderedDict(((start + timedelta(_)).strftime(r"%Y-%m"), None) for _ in range((end - start).days)).keys()
dates_series = [_ for _ in dates_dict]
#dates_series

# %%
for fpath in os.listdir(file_path)[:]:
    print(fpath)
    all_data = pd.DataFrame()
    date_range = fpath.split('.')[0].split('-')
    date_range_st = date_range[0] + date_range[1] + '%%'
    date_range_ed = date_range[0] + date_range[1] + date_range[2]
    last_day_sql_cmd = f"select TRADE_DAYS from ASHARECALENDAR where FIND_IN_SET(S_INFO_EXCHMARKET,'SSE') and \
                        TRADE_DAYS BETWEEN '{date_range_st}' and '{date_range_ed}' ORDER BY TRADE_DAYS desc limit 1"
    trade_day = pd.read_sql(sql= last_day_sql_cmd, con = engine).TRADE_DAYS.tolist()[0]
    #print(trade_day[:4],trade_day[4:6],trade_day[6:8])

    origin_df = pd.read_csv(os.path.join(file_path, fpath), engine='c',encoding='gbk', index_col=[0]).fillna(0)
    #print(origin_df.iloc[:,:8])
    sec_code = str(origin_df.index.tolist()[:])
    #origin_df = origin_df.iloc[:,:7].set_index(origin_df.code)
        
    sec_code = re.sub('[\ \[\]\']', '', sec_code)
    sec_code = f"'{sec_code}'"
    sec_code_series = f'FIND_IN_SET(S_INFO_WINDCODE,{sec_code})'
    #print(f'dealing with {fpath}')
    print(os.path.join(save_path, fpath))
    
    # round 1
    # 统计因子
    Indicator_Name = 'S_INFO_WINDCODE PCT_CHANGE_M ALPHA_DAY_1Y BETA_DAY_1Y ' + \
                     'TURNOVER_M STD_DEVIATION_24M STD_DEVIATION_60M BETA_60M ALPHA_60M ' + \
                    'TURNOVER_D_FLOAT TURNOVER_W_FLOAT TURNOVER_M_FLOAT'
    Indicator_Name = Indicator_Name.replace(' ', ',')
    #Indicator_Name = '*'
    Table_Name = 'ASHAREYIELD'
    condiction = f" WHERE TRADE_DT={trade_day} AND {sec_code_series}" 
    sql_cmd = f'select {Indicator_Name} from {Table_Name} {condiction}'
    #print(sql_cmd)
    
    print(Table_Name)
    sql_df = pd.read_sql(sql= sql_cmd, con = engine)
    sql_df = sql_df.set_index(sql_df.S_INFO_WINDCODE)
    sql_df.rename(columns={'PCT_CHANGE_M': 'PCT_CHG_NM'}, inplace=True)
    sql_df.rename(columns={'TURNOVER_D_FLOAT': 'STOA_Barra'}, inplace=True)
    sql_df.rename(columns={'TURNOVER_W_FLOAT': 'STOW_Barra'}, inplace=True)
    sql_df.rename(columns={'TURNOVER_M_FLOAT': 'STOM_Barra'}, inplace=True)
    #print(origin_df.shape,sql_df.shape)
    all_data = pd.concat([origin_df, sql_df], axis = 1)
    
    # round 2
    # 技术因子
    Indicator_Name = 'S_INFO_WINDCODE MA_20D MACD_DIFF MACD_DEA MACD_MACD'
    Indicator_Name = Indicator_Name.replace(' ', ',')
    #Indicator_Name = '*'
    Table_Name = 'ASHAREINTENSITYTREND'
    condiction = f" WHERE TRADE_DT={trade_day} AND {sec_code_series}" 
    sql_cmd = f'select {Indicator_Name} from {Table_Name} {condiction}'
    #print(sql_cmd)
            
    print(Table_Name)
    sql_df = pd.read_sql(sql= sql_cmd, con = engine)
    sql_df = sql_df.set_index(sql_df.S_INFO_WINDCODE)
    #print(origin_df.shape,sql_df.shape)
    all_data = pd.concat([all_data, sql_df], axis = 1)
    
    # round 3
    # 市值相关
    Indicator_Name = 'S_INFO_WINDCODE S_VAL_MV S_VAL_PE S_VAL_PE_TTM S_DQ_MV S_VAL_PCF_NCFTTM '+ \
                    'NET_CASH_FLOWS_OPER_ACT_TTM NET_INCR_CASH_CASH_EQU_TTM S_VAL_PB_NEW NET_PROFIT_PARENT_COMP_TTM'
    Indicator_Name = Indicator_Name.replace(' ', ',')
    Table_Name = 'ASHAREEODDERIVATIVEINDICATOR'
    condiction = f" WHERE TRADE_DT={trade_day} AND {sec_code_series}" 
    sql_cmd = f'select {Indicator_Name} from {Table_Name} {condiction}'
    #print(sql_cmd)
            
    print(Table_Name)
    sql_df = pd.read_sql(sql= sql_cmd, con = engine)
    sql_df = sql_df.set_index(sql_df.S_INFO_WINDCODE)
    sql_df['LNCAP_barra'] = np.log(sql_df.S_DQ_MV)
    sql_df['BP'] = (1 / sql_df.S_DQ_MV)
    sql_df['BTOP_Barra'] = (1 / sql_df.S_DQ_MV)
    sql_df['CETOP_Barra'] = (1 / sql_df.S_VAL_PCF_NCFTTM)
    sql_df['ETOP_Barra'] = (1 / sql_df.S_VAL_PE)
    sql_df['EP'] = (1 / sql_df.S_VAL_PE_TTM)
    sql_df['GPE'] = (sql_df.NET_PROFIT_PARENT_COMP_TTM / sql_df.S_VAL_PE_TTM)
    sql_df['OCFP'] = (1 / sql_df.NET_CASH_FLOWS_OPER_ACT_TTM)
    sql_df['NCFP'] = (1 / sql_df.NET_INCR_CASH_CASH_EQU_TTM)
    sql_df.rename(columns={'S_DQ_MV': 'MKT_CAP_FLOAT'}, inplace=True)
    #print(origin_df.shape,sql_df.shape)
    all_data = pd.concat([all_data, sql_df], axis = 1)
    
    # round 4
    # 交易状态
    Indicator_Name = 'S_INFO_WINDCODE S_DQ_TRADESTATUS'
    Indicator_Name = Indicator_Name.replace(' ', ',')
    Table_Name = 'ASHAREEODPRICES'
    condiction = f" WHERE TRADE_DT={trade_day} AND {sec_code_series}" 
    sql_cmd = f'select {Indicator_Name} from {Table_Name} {condiction}'
    #print(sql_cmd)
            
    print(Table_Name)
    sql_df = pd.read_sql(sql= sql_cmd, con = engine)
    sql_df = sql_df.set_index(sql_df.S_INFO_WINDCODE)
    #print(origin_df.shape,sql_df.shape)
    all_data = pd.concat([all_data, sql_df], axis = 1)
    
    # round 5
    # 技术相关 反转
    Indicator_Name = 'S_INFO_WINDCODE BIAS'
    Indicator_Name = Indicator_Name.replace(' ', ',')
    Table_Name = 'ASHARESWINGREVERSETREND'
    condiction = f" WHERE TRADE_DT={trade_day} AND {sec_code_series}" 
    sql_cmd = f'select {Indicator_Name} from {Table_Name} {condiction}'
    #print(sql_cmd)
            
    print(Table_Name)
    sql_df = pd.read_sql(sql= sql_cmd, con = engine)
    sql_df = sql_df.set_index(sql_df.S_INFO_WINDCODE)
    #print(origin_df.shape,sql_df.shape)
    all_data = pd.concat([all_data, sql_df], axis = 1)
    
    # round 6
    # 财务因子
    #日期控制器
    _date = parse(trade_day)
    quarter = (_date.month - 1) // 3 + 1
    if quarter == 1:
        rp = (_date.year - 1, 12, 31)
    elif quarter == 2:
        rp = (_date.year, 3, 31)
    elif quarter == 3:
        rp = (_date.year, 6, 30)
    else:
        rp = (_date.year, 9, 30)

    report_p = str(rp[0])+str(rp[1])+str(rp[2])
    report_p = pd.to_datetime(report_p, format = '%Y%m%d').strftime('%Y%m%d')
    
    Indicator_Name = 'S_INFO_WINDCODE S_QFA_ROE S_QFA_ROE_DEDUCTED'
    Indicator_Name = Indicator_Name.replace(' ', ',')
    Table_Name = 'ASHAREFINANCIALINDICATOR'
    condiction = f" WHERE REPORT_PERIOD={report_p} AND {sec_code_series}" 
    sql_cmd = f'select {Indicator_Name} from {Table_Name} {condiction}'
           
    print(Table_Name)
    sql_df = pd.read_sql(sql= sql_cmd, con = engine)
    sql_df = sql_df.set_index(sql_df.S_INFO_WINDCODE)
    #print(origin_df.shape,sql_df.shape)
    all_data = pd.concat([all_data, sql_df], axis = 1)
    
    
    ########################################################################################################
    
    all_data = all_data.reset_index(drop = True)
    all_data['is_open1'] = all_data.S_DQ_TRADESTATUS.apply(lambda x:'TRUE' if x == '交易' else 'FALSE')
    all_data = all_data.dropna(subset=['S_DQ_TRADESTATUS'])
    del all_data['S_INFO_WINDCODE']
    del all_data['S_DQ_TRADESTATUS']
    
    all_data = all_data.dropna()
    all_data['No'] = all_data.index
    all_data = all_data.set_index(all_data.No, drop = True)
    all_data.rename(columns = {'code.1':'code'},inplace = True)
    
    all_data.to_csv(os.path.join(save_path, fpath), encoding='gbk')
# Out:
# 2014-09-30.csv
# /AI2/IE/factor_preprocess/factors/2014-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-10-31.csv
# /AI2/IE/factor_preprocess/factors/2018-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-11-30.csv
# /AI2/IE/factor_preprocess/factors/2014-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-01-31.csv
# /AI2/IE/factor_preprocess/factors/2019-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-12-31.csv
# /AI2/IE/factor_preprocess/factors/2019-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-03-31.csv
# /AI2/IE/factor_preprocess/factors/2019-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-03-31.csv
# /AI2/IE/factor_preprocess/factors/2013-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-12-31.csv
# /AI2/IE/factor_preprocess/factors/2018-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-04-30.csv
# /AI2/IE/factor_preprocess/factors/2016-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2020-03-31.csv
# /AI2/IE/factor_preprocess/factors/2020-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-07-31.csv
# /AI2/IE/factor_preprocess/factors/2014-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-04-30.csv
# /AI2/IE/factor_preprocess/factors/2014-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-05-31.csv
# /AI2/IE/factor_preprocess/factors/2018-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-06-30.csv
# /AI2/IE/factor_preprocess/factors/2017-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-07-31.csv
# /AI2/IE/factor_preprocess/factors/2018-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-08-31.csv
# /AI2/IE/factor_preprocess/factors/2016-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-11-30.csv
# /AI2/IE/factor_preprocess/factors/2018-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-07-31.csv
# /AI2/IE/factor_preprocess/factors/2016-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-04-30.csv
# /AI2/IE/factor_preprocess/factors/2019-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-06-30.csv
# /AI2/IE/factor_preprocess/factors/2015-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-02-28.csv
# /AI2/IE/factor_preprocess/factors/2015-02-28.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-03-31.csv
# /AI2/IE/factor_preprocess/factors/2017-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-09-30.csv
# /AI2/IE/factor_preprocess/factors/2019-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-06-30.csv
# /AI2/IE/factor_preprocess/factors/2018-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2020-05-31.csv
# /AI2/IE/factor_preprocess/factors/2020-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-08-31.csv
# /AI2/IE/factor_preprocess/factors/2019-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-10-31.csv
# /AI2/IE/factor_preprocess/factors/2016-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-04-30.csv
# /AI2/IE/factor_preprocess/factors/2017-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-05-31.csv
# /AI2/IE/factor_preprocess/factors/2017-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-05-31.csv
# /AI2/IE/factor_preprocess/factors/2014-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-02-29.csv
# /AI2/IE/factor_preprocess/factors/2016-02-29.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-10-31.csv
# /AI2/IE/factor_preprocess/factors/2014-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-08-31.csv
# /AI2/IE/factor_preprocess/factors/2015-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-08-31.csv
# /AI2/IE/factor_preprocess/factors/2018-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-04-30.csv
# /AI2/IE/factor_preprocess/factors/2013-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-11-30.csv
# /AI2/IE/factor_preprocess/factors/2015-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-01-31.csv
# /AI2/IE/factor_preprocess/factors/2017-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-11-30.csv
# /AI2/IE/factor_preprocess/factors/2017-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-12-31.csv
# /AI2/IE/factor_preprocess/factors/2017-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-03-31.csv
# /AI2/IE/factor_preprocess/factors/2018-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-05-31.csv
# /AI2/IE/factor_preprocess/factors/2015-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-07-31.csv
# /AI2/IE/factor_preprocess/factors/2013-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-01-31.csv
# /AI2/IE/factor_preprocess/factors/2018-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-09-30.csv
# /AI2/IE/factor_preprocess/factors/2015-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-02-28.csv
# /AI2/IE/factor_preprocess/factors/2013-02-28.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-07-31.csv
# /AI2/IE/factor_preprocess/factors/2019-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2020-06-30.csv
# /AI2/IE/factor_preprocess/factors/2020-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-02-28.csv
# /AI2/IE/factor_preprocess/factors/2017-02-28.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-05-31.csv
# /AI2/IE/factor_preprocess/factors/2016-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-09-30.csv
# /AI2/IE/factor_preprocess/factors/2018-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-03-31.csv
# /AI2/IE/factor_preprocess/factors/2015-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-02-28.csv
# /AI2/IE/factor_preprocess/factors/2014-02-28.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-12-31.csv
# /AI2/IE/factor_preprocess/factors/2016-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-11-30.csv
# /AI2/IE/factor_preprocess/factors/2013-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-09-30.csv
# /AI2/IE/factor_preprocess/factors/2013-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-02-28.csv
# /AI2/IE/factor_preprocess/factors/2018-02-28.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-01-31.csv
# /AI2/IE/factor_preprocess/factors/2016-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-12-31.csv
# /AI2/IE/factor_preprocess/factors/2014-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-03-31.csv
# /AI2/IE/factor_preprocess/factors/2014-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-02-28.csv
# /AI2/IE/factor_preprocess/factors/2019-02-28.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-08-31.csv
# /AI2/IE/factor_preprocess/factors/2013-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-06-30.csv
# /AI2/IE/factor_preprocess/factors/2016-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-09-30.csv
# /AI2/IE/factor_preprocess/factors/2016-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-05-31.csv
# /AI2/IE/factor_preprocess/factors/2019-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-10-31.csv
# /AI2/IE/factor_preprocess/factors/2019-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-11-30.csv
# /AI2/IE/factor_preprocess/factors/2019-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-07-31.csv
# /AI2/IE/factor_preprocess/factors/2015-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-10-31.csv
# /AI2/IE/factor_preprocess/factors/2013-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2020-01-31.csv
# /AI2/IE/factor_preprocess/factors/2020-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2020-04-30.csv
# /AI2/IE/factor_preprocess/factors/2020-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2020-02-29.csv
# /AI2/IE/factor_preprocess/factors/2020-02-29.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-12-31.csv
# /AI2/IE/factor_preprocess/factors/2015-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-05-31.csv
# /AI2/IE/factor_preprocess/factors/2013-05-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-11-30.csv
# /AI2/IE/factor_preprocess/factors/2016-11-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2018-04-30.csv
# /AI2/IE/factor_preprocess/factors/2018-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2019-06-30.csv
# /AI2/IE/factor_preprocess/factors/2019-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-01-31.csv
# /AI2/IE/factor_preprocess/factors/2015-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-09-30.csv
# /AI2/IE/factor_preprocess/factors/2017-09-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-06-30.csv
# /AI2/IE/factor_preprocess/factors/2013-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2016-03-31.csv
# /AI2/IE/factor_preprocess/factors/2016-03-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-07-31.csv
# /AI2/IE/factor_preprocess/factors/2017-07-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-08-31.csv
# /AI2/IE/factor_preprocess/factors/2017-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-08-31.csv
# /AI2/IE/factor_preprocess/factors/2014-08-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-04-30.csv
# /AI2/IE/factor_preprocess/factors/2015-04-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2013-12-31.csv
# /AI2/IE/factor_preprocess/factors/2013-12-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2015-10-31.csv
# /AI2/IE/factor_preprocess/factors/2015-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-01-31.csv
# /AI2/IE/factor_preprocess/factors/2014-01-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2014-06-30.csv
# /AI2/IE/factor_preprocess/factors/2014-06-30.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
# 2017-10-31.csv
# /AI2/IE/factor_preprocess/factors/2017-10-31.csv
# ASHAREYIELD
# ASHAREINTENSITYTREND
# ASHAREEODDERIVATIVEINDICATOR
# ASHAREEODPRICES
# ASHARESWINGREVERSETREND
# ASHAREFINANCIALINDICATOR
